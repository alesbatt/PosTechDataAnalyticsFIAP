# %% [markdown]
# ###### $$ \alpha + \beta = 10$$

# %%
import numpy as np
import scipy as sc
import sympy as sy
import pandas as pd

# %%
x2 = np.array([1,2,3]) #vetor com três elementos escalares
x2
# Out:
# array([1, 2, 3])

# %%
x3 = np.array([[1],[2],[3]]) #matriz com três elementos vetores com elementos escalares
x4
# Out:
# array([[1],
#        [2],
#        [3]])

# %%
x4 = np.array([[1,2,3],[1,2,3],[1,2,3]]) #matriz quadrada tradicional
x4
# Out:
# array([[1, 2, 3],
#        [1, 2, 3],
#        [1, 2, 3]])

# %%
print(x2)
print() #só pra pular uma linha
print(x3)
print() 
print(x4)
# Out:
# [1 2 3]
#
# [[1]
#  [2]
#  [3]]
#
# [[1 2 3]
#  [1 2 3]
#  [1 2 3]]

# %%
lista = [1,2,3,4,5] #ou np.array([1,2,3,4,5])
df = pd.DataFrame({'coluna 1':lista}) #melhor trabalhar com dicionários em pandas

# %%
df
# Out:
#    coluna 1
# 0         1
# 1         2
# 2         3
# 3         4
# 4         5

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df = pd.DataFrame({'coluna':lista, 'coluna 2':lista})
df
# Out:
#    coluna  coluna 2
# 0       1         1
# 1       2         2
# 2       3         3
# 3       4         4
# 4       5         5

# %%
type(df.coluna)
# Out:
# pandas.core.series.Series

# %%
lista[-1] #pega o último elemento do vetor
# Out:
# 5

# %%
lista[-2] #pega o penúltimo elemento do vetor
# Out:
# 4

# %%
lista[1:] #slice que pega do elemento de índice 1 para frente
# Out:
# [2, 3, 4, 5]

# %%
lista[:1] #slice que pega do elemento de índice 1 para trás
# Out:
# [1]

# %%
x2 + x3
# Out:
# array([[2, 3, 4],
#        [3, 4, 5],
#        [4, 5, 6]])

# %%
x3 + x4
# Out:
# array([[2, 3, 4],
#        [3, 4, 5],
#        [4, 5, 6]])

# %%
x5 = np.array([[1],[2]])
x5
# Out:
# array([[1],
#        [2]])

# %%
np.dot(x4,x3)
# Out:
# array([[14],
#        [14],
#        [14]])

# %%
x4@x3
# Out:
# array([[14],
#        [14],
#        [14]])
